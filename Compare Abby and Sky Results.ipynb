# %% [markdown]
# This notebook is some work in progress that compares the methods used in my derivation of Abby's original name processing code that used the R-Taxize package in an interactive way. The query looks for cases where Abby's process found a match, but my process, designed to be run in a completely automated way, did not. I used this to tease out some remaining pesky issues in the ITIS notebook for the TIR. When I left this off, there were only 29 names that the new process did not work out.
#
# In reviewing these remaining cases, I found the following issues that I don't think are resolvable but that I also don't think are showstoppers for running this in an automated way:
#
# * There are cases at higher taxonomic levels where there is more than one taxon that is "valid" or "accepted" in ITIS. There are other annotation properties that indicate the level of completeness. Using a human-driven process with R Taxize or something like it, a user can select based on this annotation. My current process moves on and records a negative result if there is more than one match based on a search that now constrains to "valid" or "accepted." While we could tweak the algorithm to look for clues in the completeness properties and make a reasonable selection, I don't think it's worth adding that complexity for the relative rare cases where it would come up.
#
# * There are cases where it looks like Abby might have done some additional work as the script was running. Some names do not come up in any kind of search. Following the selections that I think Abby made interactively, I can see that Genus names changed or other things are quite different. We might eventually deal with this in the Taxonomic Information Registry by building some kind of annotation structure that would link names we encounter in the registry to something we know that is not captured in a taxonomic authority. That could then be fed into processing algorithms to use in going after improved information. There are also probably some more complex searches we could run by going to the Genus or other higher taxonomy level and then exploring the tree, but the gain in additional name matches doesn't seem worth it at this time.
#
# * There are a couple cases of additional scientific name shorthand that Abby cleaned up (e.g., "Procambarus h. hagenianus" to "Procambarus hagenianus hagenianus"). We could also see about handling this in the cleaning function, but it will be a little challenging to tease out those cases from those where the intent of abbreviated strings in the name means something different. Again, the gain is not worth it at this time.

# %%
import requests,configparser
from IPython.display import display

# %%
# Get API keys and any other config details from a file that is external to the code.
config = configparser.RawConfigParser()
config.read_file(open(r'../config/stuff.py'))

# %%
# Build base URL with API key using input from the external config.
def getBaseURL():
    gc2APIKey = config.get('apiKeys','apiKey_GC2_BCB').replace('"','')
    apiBaseURL = "https://gc2.mapcentia.com/api/v1/sql/bcb?key="+gc2APIKey
    return apiBaseURL

# %%
q = "SELECT DISTINCT ON (taxonomicauthorityid_accepted) \
    taxonomicauthorityid_accepted, scientificname_submitted, scientificname_cleaned \
    FROM public.sgcn \
    WHERE taxonomicauthorityid_accepted LIKE '%itis%' AND \
    taxonomicauthorityid_accepted NOT IN \
    (SELECT taxonomicauthorityid FROM sgcn.sgcn_nationallist)"
r = requests.get(getBaseURL()+"&q="+q).json()

recordCount = 0

for feature in r["features"]:
    print ("ITIS ID: "+feature["properties"]["taxonomicauthorityid_accepted"])
    print ("Submitted name: "+feature["properties"]["scientificname_submitted"])
    print ("Abby's clean name: "+feature["properties"]["scientificname_cleaned"])
    print ("----")
#    print (requests.get(getBaseURL()+"&q=UPDATE tir.tir2 SET itis = Null WHERE registration->'SGCN_ScientificName_Submitted' = '"+feature["properties"]["scientificname_submitted"]+"'").json())
    recordCount = recordCount + 1

print (recordCount)
# Out:
# ITIS ID: http://services.itis.gov/?q=tsn:100825
# Submitted name: Baetis brunneicolor
# Abby's clean name: Baetis brunneicolor
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:101584
# Submitted name: Tortopus circumfluus
# Abby's clean name: Tortopus circumfluus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:101869
# Submitted name: Erythemis vesiculosa
# Abby's clean name: Erythemis vesiculosa
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:102026
# Submitted name: Cordulegastridae
# Abby's clean name: Cordulegastridae
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:102802
# Submitted name: Taeniopteryx starki
# Abby's clean name: Taeniopteryx starki
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:103067
# Submitted name: Isoperla sagittata
# Abby's clean name: Isoperla sagittata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:110182
# Submitted name: Pseudanophthalmus grandis orthosulc
# Abby's clean name: Pseudanophthalmus grandis orthosulc
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:115700
# Submitted name: Hydroptila melia
# Abby's clean name: Hydroptila melia
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:115711
# Submitted name: Hydroptila ouachita
# Abby's clean name: Hydroptila ouachita
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:115737
# Submitted name: Ochrotrichia capitana
# Abby's clean name: Ochrotrichia capitana
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:115767
# Submitted name: Ochrotrichia trapoiza
# Abby's clean name: Ochrotrichia trapoiza
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:115846
# Submitted name: Neotrichia sonora
# Abby's clean name: Neotrichia sonora
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:115966
# Submitted name: Anabolia ozburni
# Abby's clean name: Anabolia ozburni
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:116117
# Submitted name: Limnephilus adapus
# Abby's clean name: Limnephilus adapus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:116676
# Submitted name: Nectopsyche texana
# Abby's clean name: Nectopsyche texana
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:117004
# Submitted name: Gumaga griseola
# Abby's clean name: Gumaga griseola
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:139621
# Submitted name: Syrphidae
# Abby's clean name: Syrphidae
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:152732
# Submitted name: Siphonaptera
# Abby's clean name: Siphonaptera
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:156880
# Submitted name: Luidia senegalensis
# Abby's clean name: Luidia senegalensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:157927
# Submitted name: Lytechinus williamsi
# Abby's clean name: Lytechinus williamsi
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:157994
# Submitted name: Clypeaster chesheri
# Abby's clean name: Clypeaster chesheri
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:158318
# Submitted name: Holothuria occidentalis
# Abby's clean name: Holothuria occidentalis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:158330
# Submitted name: Holothuria mexicana
# Abby's clean name: Holothuria mexicana
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:158332
# Submitted name: Holothuria parvula
# Abby's clean name: Holothuria parvula
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:169744
# Submitted name: Embiotoca������ lateralis
# Abby's clean name: Embiotoca������ lateralis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:174248
# Submitted name: Nerodia fasciata
# Abby's clean name: Nerodia fasciata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:174303
# Submitted name: Sistrurus miliarius miliarius
# Abby's clean name: Sistrurus miliarius miliarius
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:188712
# Submitted name: Lithophane l. lepida
# Abby's clean name: Lithophane lepida
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:20347
# Submitted name: Paronychia lundellorum
# Abby's clean name: Paronychia lundellorum
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:206620
# Submitted name: Acerpenna pygmaea
# Abby's clean name: Acerpenna pygmaea
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:206817
# Submitted name: Echinaster echinophorus
# Abby's clean name: Echinaster echinophorus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:209099
# Submitted name: Thamnophis sirtalis parietalis
# Abby's clean name: Thamnophis sirtalis parietalis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:22450
# Submitted name: Populus ������acuminata
# Abby's clean name: Populus ������acuminata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:22472
# Submitted name: Populus ������smithii
# Abby's clean name: Populus ������smithii
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:28137
# Submitted name: Chamaesyce polycarpa var. simulans
# Abby's clean name: Chamaesyce polycarpa var. simulans
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:34359
# Submitted name: Justicia warnockii
# Abby's clean name: Justicia warnockii
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:39912
# Submitted name: Cyperus cephalanthus
# Abby's clean name: Cyperus cephalanthus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:40178
# Submitted name: Rhynchospora indianolensis
# Abby's clean name: Rhynchospora indianolensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:42076
# Submitted name: Schizachyrium spadiceum
# Abby's clean name: Schizachyrium spadiceum
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:503363
# Submitted name: Lenophyllum texanum
# Abby's clean name: Lenophyllum texanum
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:503869
# Submitted name: Moneses uniflora
# Abby's clean name: Moneses uniflora
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:504710
# Submitted name: Quercus graciliformis
# Abby's clean name: Quercus graciliformis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:50889
# Submitted name: Stylasteridae
# Abby's clean name: Stylasteridae
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:535318
# Submitted name: Chamaesyce celastroides var. kaenana
# Abby's clean name: Chamaesyce celastroides var. kaenana
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:535335
# Submitted name: Chamaesyce chaetocalyx var. triligulata
# Abby's clean name: Chamaesyce chaetocalyx var. triligulata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:553377
# Submitted name: Etheostoma sp. cf. bellator
# Abby's clean name: Etheostoma. bellator
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:554134
# Submitted name: Aplonis tabuensis manuae/tutuilae
# Abby's clean name: Aplonis tabuensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:567269
# Submitted name: Balconorbis uvaldensis
# Abby's clean name: Balconorbis uvaldensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:567359
# Submitted name: Chromodoris kempfi
# Abby's clean name: Chromodoris kempfi
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:567636
# Submitted name: Glossodoris sedna
# Abby's clean name: Glossodoris sedna
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:568041
# Submitted name: Ostrea conchaphila
# Abby's clean name: Ostrea conchaphila
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:568088
# Submitted name: Phreatodrobia coronae
# Abby's clean name: Phreatodrobia coronae
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:568365
# Submitted name: Texapyrgus longleyi
# Abby's clean name: Texapyrgus longleyi
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:568581
# Submitted name: Baetodes alleni
# Abby's clean name: Baetodes alleni
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:568622
# Submitted name: Pseudocentroptiloides morihari
# Abby's clean name: Pseudocentroptiloides morihari
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:568635
# Submitted name: Ephemerella apopsis
# Abby's clean name: Ephemerella apopsis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:568679
# Submitted name: Labiobaetis apache
# Abby's clean name: Labiobaetis apache
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:593042
# Submitted name: Cordulegaster dorsalis
# Abby's clean name: Cordulegaster dorsalis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:594681
# Submitted name: Brackenridgia reddelli
# Abby's clean name: Brackenridgia reddelli
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:598943
# Submitted name: Phylocentropus harrisi
# Abby's clean name: Phylocentropus harrisi
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:598967
# Submitted name: Austrotinodes texensis
# Abby's clean name: Austrotinodes texensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:599605
# Submitted name: Cheumatopsyche morsei
# Abby's clean name: Cheumatopsyche morsei
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:601550
# Submitted name: Xiphocentron messapus
# Abby's clean name: Xiphocentron messapus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:601789
# Submitted name: Wormaldia arizonensis
# Abby's clean name: Wormaldia arizonensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:602029
# Submitted name: Chimarra holzenthali
# Abby's clean name: Chimarra holzenthali
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:606269
# Submitted name: Protoptila balmorhea
# Abby's clean name: Protoptila balmorhea
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:606736
# Submitted name: Oxyethira ulmeri
# Abby's clean name: Oxyethira ulmeri
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:607062
# Submitted name: Neotrichia juani
# Abby's clean name: Neotrichia juani
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:607071
# Submitted name: Neotrichia mobilensis
# Abby's clean name: Neotrichia mobilensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:607187
# Submitted name: Ochrotrichia guadalupensis
# Abby's clean name: Ochrotrichia guadalupensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:609563
# Submitted name: Plauditus texanus
# Abby's clean name: Plauditus texanus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:609580
# Submitted name: Procloeon distinctum
# Abby's clean name: Procloeon distinctum
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:609634
# Submitted name: Tricorythodes curvatus
# Abby's clean name: Tricorythodes curvatus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:609642
# Submitted name: Farrodes mexicanus
# Abby's clean name: Farrodes mexicanus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:609872
# Submitted name: Allocapnia starki
# Abby's clean name: Allocapnia starki
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:612592
# Submitted name: B. bonaerensis
# Abby's clean name: Balaenoptera bonaerensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:624281
# Submitted name: Archaeognatha
# Abby's clean name: Archaeognatha
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:650388
# Submitted name: Procambarus ceruleus
# Abby's clean name: Procambarus ceruleus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:650434
# Submitted name: Procambarus h. hagenianus
# Abby's clean name: Procambarus hagenianus hagenianus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:656702
# Submitted name: Artesia welbourni
# Abby's clean name: Artesia welbourni
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:656708
# Submitted name: Parabogidiella americana
# Abby's clean name: Parabogidiella americana
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:656845
# Submitted name: Allotexiweckelia hirsuta
# Abby's clean name: Allotexiweckelia hirsuta
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:656852
# Submitted name: Mexiweckelia hardeni
# Abby's clean name: Mexiweckelia hardeni
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:656853
# Submitted name: Paramexiweckelia ruffoi
# Abby's clean name: Paramexiweckelia ruffoi
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:657306
# Submitted name: Seborgia hershleri
# Abby's clean name: Seborgia hershleri
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:657307
# Submitted name: Seborgia relicta
# Abby's clean name: Seborgia relicta
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:657863
# Submitted name: Amblycorypha uhleri
# Abby's clean name: Amblycorypha uhleri
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:657890
# Submitted name: Arethaea ambulator
# Abby's clean name: Arethaea ambulator
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:658157
# Submitted name: Dichopetala catinata
# Abby's clean name: Dichopetala catinata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:658247
# Submitted name: Heliastus subroseus
# Abby's clean name: Heliastus subroseus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:658639
# Submitted name: Paracyrtophyllus excelsus
# Abby's clean name: Paracyrtophyllus excelsus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:67152
# Submitted name: Monticellina sp.
# Abby's clean name: Monticellina
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:683366
# Submitted name: Lirceolus bisetus
# Abby's clean name: Lirceolus bisetus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:683367
# Submitted name: Lirceolus hardeni
# Abby's clean name: Lirceolus hardeni
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:683368
# Submitted name: Lirceolus pilus
# Abby's clean name: Lirceolus pilus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:694410
# Submitted name: Triepeolus rugosus
# Abby's clean name: Triepeolus rugosus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:698074
# Submitted name: Caenis arwini
# Abby's clean name: Caenis arwini
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:69816
# Submitted name: Calliostoma javanicum
# Abby's clean name: Calliostoma javanicum
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:703036
# Submitted name: Stizocera floridana
# Abby's clean name: Stizocera floridana
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:703189
# Submitted name: Prionus spinipennis
# Abby's clean name: Prionus spinipennis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:706726
# Submitted name: Celotes limpia
# Abby's clean name: Celotes limpia
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:70692
# Submitted name: Phreatodrobia conica
# Abby's clean name: Phreatodrobia conica
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:70696
# Submitted name: Phreatodrobia punctata
# Abby's clean name: Phreatodrobia punctata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:70698
# Submitted name: Phreatodrobia nugax
# Abby's clean name: Phreatodrobia nugax
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:70711
# Submitted name: Stygopyrgus bartonensis
# Abby's clean name: Stygopyrgus bartonensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:70776
# Submitted name: Amnicola rhombostoma
# Abby's clean name: Amnicola rhombostoma
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:708675
# Submitted name: Myrmecoderus laevipennis
# Abby's clean name: Myrmecoderus laevipennis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:716409
# Submitted name: Perdita townesi
# Abby's clean name: Perdita townesi
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:721221
# Submitted name: Cryptocephalus downiei
# Abby's clean name: Cryptocephalus downiei
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:72559
# Submitted name: Strombus gallus
# Abby's clean name: Strombus gallus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:726985
# Submitted name: Ursus arctos kenai
# Abby's clean name: Ursus arctos kenai
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:72767
# Submitted name: Cypraea zebra
# Abby's clean name: Cypraea zebra
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:72775
# Submitted name: Cyphoma mcgintyi
# Abby's clean name: Cyphoma mcgintyi
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:76577
# Submitted name: Laevapex fuscus
# Abby's clean name: Laevapex fuscus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:77018
# Submitted name: Liguus fasciatus
# Abby's clean name: Liguus fasciatus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:774545
# Submitted name: Pseudacris fouquettei
# Abby's clean name: Pseudacris fouquettei
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:776965
# Submitted name: Sparbarus coushatta
# Abby's clean name: Sparbarus coushatta
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:776973
# Submitted name: Susperatus tonkawa
# Abby's clean name: Susperatus tonkawa
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:777827
# Submitted name: Fixsenia (Satyrium) ilavia
# Abby's clean name: Satyrium ilavia
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:777828
# Submitted name: Satyrium polingi
# Abby's clean name: Satyrium polingi
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:778725
# Submitted name: Callophrys affinis homoperplexa
# Abby's clean name: Callophrys affinis homoperplexa
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:78049
# Submitted name: Dolabrifera dolabrifera
# Abby's clean name: Dolabrifera dolabrifera
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:803839
# Submitted name: Coleataenia longifolia ssp. longifolia
# Abby's clean name: Coleataenia longifolia ssp. longifolia
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:81393
# Submitted name: Sphaerium fabale
# Abby's clean name: Sphaerium fabale
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:81397
# Submitted name: Sphaerium simile
# Abby's clean name: Sphaerium simile
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:81398
# Submitted name: Sphaerium striatinum
# Abby's clean name: Sphaerium striatinum
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:81406
# Submitted name: Pisidium compressum
# Abby's clean name: Pisidium compressum
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:81408
# Submitted name: Pisidium fallax
# Abby's clean name: Pisidium fallax
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:81434
# Submitted name: Musculium securis
# Abby's clean name: Musculium securis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:823088
# Submitted name: Physaria angustifolia
# Abby's clean name: Physaria angustifolia
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:825149
# Submitted name: Tringa semipalmata semipalmata
# Abby's clean name: Tringa semipalmata semipalmata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:82607
# Submitted name: Octopus joubini
# Abby's clean name: Octopus joubini
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:82615
# Submitted name: Octopus burryi
# Abby's clean name: Octopus burryi
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:83711
# Submitted name: Streptocephalus linderi
# Abby's clean name: Streptocephalus linderi
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:83784
# Submitted name: Paralimnetis texana
# Abby's clean name: Paralimnetis texana
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:886145
# Submitted name: Pelegrina arizonensis
# Abby's clean name: Pelegrina arizonensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:894826
# Submitted name: Neottia cordata
# Abby's clean name: Neottia cordata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:92282
# Submitted name: Speocirolana hardeni
# Abby's clean name: Speocirolana hardeni
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:928286
# Submitted name: Polyphylla monahansensis
# Abby's clean name: Polyphylla monahansensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:928298
# Submitted name: Polyphylla pottsorum
# Abby's clean name: Polyphylla pottsorum
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:929404
# Submitted name: Cotinis boylei
# Abby's clean name: Cotinis boylei
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:93039
# Submitted name: Mexistenasellus coahuila
# Abby's clean name: Mexistenasellus coahuila
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:931149
# Submitted name: Eutamias cinereicollis
# Abby's clean name: Eutamias cinereicollis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:931312
# Submitted name: Eutamias quadrivittatus
# Abby's clean name: Eutamias quadrivittatus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:931782
# Submitted name: Pseudanophthalmus grandis ssp 1
# Abby's clean name: Pseudanophthalmus grandis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:931785
# Submitted name: Rhadine speca
# Abby's clean name: Rhadine speca
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:931786
# Submitted name: Rhadine subterranea
# Abby's clean name: Rhadine subterranea
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:936182
# Submitted name: Hemileuca (chinatiensis) comwayae
# Abby's clean name: Hemileuca chinatiensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:938208
# Submitted name: Cisthene conjuncta
# Abby's clean name: Cisthene conjuncta
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:938279
# Submitted name: Copablepharon columbia
# Abby's clean name: Copablepharon columbia
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:938301
# Submitted name: Anarta luteola
# Abby's clean name: Anarta luteola
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:938400
# Submitted name: Dasychira atrivenosa
# Abby's clean name: Dasychira atrivenosa
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:938623
# Submitted name: Eupseudomorpha brillians
# Abby's clean name: Eupseudomorpha brillians
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:940087
# Submitted name: Pygarctia lorula
# Abby's clean name: Pygarctia lorula
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:940112
# Submitted name: Renia sp. 1 nr. Discoloralis
# Abby's clean name: Renia. Discoloralis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:941697
# Submitted name: Aspitates aberrata
# Abby's clean name: Aspitates aberrata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:942782
# Submitted name: Itame sp. 1 nr. Inextricata
# Abby's clean name: Itame. Inextricata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:948630
# Submitted name: Myotis volans (longicrus)
# Abby's clean name: Myotis volans longicrus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:96403
# Submitted name: Palaemonetes antrorum
# Abby's clean name: Palaemonetes antrorum
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:96407
# Submitted name: Palaemonetes texanus
# Abby's clean name: Palaemonetes texanus
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:97728
# Submitted name: Enoplometopus antillensis
# Abby's clean name: Enoplometopus antillensis
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:98675
# Submitted name: Cancer magister
# Abby's clean name: Cancer magister
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:989473
# Submitted name: Asterina folium
# Abby's clean name: Asterina folium
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:989751
# Submitted name: Copidaster lymani
# Abby's clean name: Copidaster lymani
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:990800
# Submitted name: Poraniella echinulata
# Abby's clean name: Poraniella echinulata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:99419
# Submitted name: Folsomia sp. 2 nr. macrochaeta
# Abby's clean name: Folsomia. macrochaeta
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:99840
# Submitted name: Pseudosinella sp. 7 nr. Nata
# Abby's clean name: Pseudosinella. Nata
# ----
# ITIS ID: http://services.itis.gov/?q=tsn:99885
# Submitted name: Oncopodura iowae
# Abby's clean name: Oncopodura iowae
# ----
# ITIS ID: https://services.itis.gov/?q=tsn:102123
# Submitted name: Enallagma optimolocus
# Abby's clean name: Enallagma optimolocus
# ----
# 169
