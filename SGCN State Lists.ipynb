# %% [markdown]
# This notebook shows the essential query for individual SGCN state lists from the structure created in the sgcn schema of the experimental GC2 instance. The whole system has been completely rebuilt from the source repository out. The "Process SGCN repository source files.ipynb" (and its corresponding py script) in this repo is what executes that process starting with all the source files in the ScienceBase Repository.
#
# We are also making some tweaks to the design of the SWAP application where we want to stick with the overall philosophy that we always show exactly what the states submitted on the state pages of the apps. The National List shows what we add to the process by aligning with taxonomic authorities and making judgments on how we group the information. To aid in this process and show full transparency, we added a few additional properties to the sgcn.sgcn table so that each record traces back to its original source. These include sourcid (ScienceBase item URI/URL) along with sourcefileurl and sourcefilename (the actual file processed by the code to produce the data for a given state and year).
#
# Data for the states can be pulled from a database view or its corresponding ElasticSearch index. The view uses the following SQL:
# ```sql
# SELECT s.sgcn_state, s.scientificname_submitted AS scientificname,
# (array_agg(s.commonname_submitted ORDER BY s.sgcn_year DESC))[1] AS commonname,
# (array_agg(s.taxonomicgroup_submitted))[1] AS taxonomicgroup,
# sum(((s.sgcn_year = 2005))::integer) AS sgcn2005,
# sum(((s.sgcn_year = 2015))::integer) AS sgcn2015,
# (array_agg(split_part(t.itis->'itisMatchMethod', ':', 1)))[1] AS itismatchmethod,
# (array_agg(split_part(t.itis->'itisMatchMethod', ':', 2)))[1] AS itismatchmethod_searchstring,
# (array_agg(t.itis->'cacheDate'))[1] AS itis_cachedate,
# (array_agg(t.itis->'nameWInd'))[1] AS namewind,
# (array_agg(t.itis->'tsn'))[1] AS tsn,
# (array_agg(t.itis->'discoveredTSN'))[1] AS discoveredtsn,
# (array_agg(t.itis->'acceptedTSN'))[1] AS acceptedtsn
# FROM sgcn.sgcn s
# JOIN tir.tir2 t ON
# s.scientificname_submitted = t.registration->'SGCN_ScientificName_Submitted'
# GROUP BY sgcn_state,scientificname_submitted
# ```
# This view makes the following choices:
# * Group on the scientific name submitted by the state
# * Use the latest common name and taxonomic group provided for species (2015 vs. 2005)

# %%
import requests
from IPython.display import display

# %%
# Available States
q = "SELECT DISTINCT sgcn_state FROM sgcn.sgcn GROUP BY sgcn_state"

r = requests.get("https://gc2.mapcentia.com/api/v1/sql/bcb?q="+q).json()

display (r)
# Out:
# {'_execution_time': 0.117,
#  'auth_check': {'auth_level': 'Write',
#   'checked_relations': ['sgcn.sgcn'],
#   'session': None,
#   'success': True},
#  'features': [{'properties': {'sgcn_state': 'Alabama'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Indiana'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Minnesota'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'South Carolina'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Louisiana'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'California'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'New Mexico'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'New Hampshire'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'American Samoa'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Connecticut'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Alaska'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Nevada'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Oklahoma'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Maryland'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Idaho'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Ohio'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Delaware'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Maine'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Florida'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Montana'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Illinois'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Oregon'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Texas'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Rhode Island'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Mississippi'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Kansas'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'New Jersey'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Puerto Rico'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Wisconsin'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Pennsylvania'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Tennessee'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'New York'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Georgia'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Vermont'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Colorado'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Virgin Islands'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Arkansas'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Hawaii'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Washington'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'North Dakota'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Virginia'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Wyoming'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'West Virginia'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Missouri'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Iowa'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Guam'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Northern Mariana Islands'},
#    'type': 'Feature'},
#   {'properties': {'sgcn_state': 'South Dakota'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'District of Columbia'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Arizona'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Utah'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'North Carolina'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Kentucky'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Nebraska'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Massachusetts'}, 'type': 'Feature'},
#   {'properties': {'sgcn_state': 'Michigan'}, 'type': 'Feature'}],
#  'forGrid': [{'dataIndex': 'sgcn_state',
#    'header': 'sgcn_state',
#    'type': 'character varying',
#    'typeObj': None}],
#  'forStore': [{'name': 'sgcn_state', 'type': 'character varying'}],
#  'success': True,
#  'type': 'FeatureCollection'}

# %%
# ElasticSearch API query for a state showing pagination method
stateName = 'Wyoming'

stateListQuery = "https://gc2.mapcentia.com/api/v1/elasticsearch/search/bcb/sgcn/sgcn_statelists?q={%22query%22:{%22match%22:{%22properties.sgcn_state%22:%22"+stateName+"%22}}}&size=25&from=50"

stateList = requests.get(stateListQuery).json()

display (stateList)
# Out:
# {'_shards': {'failed': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': 'AVxabwk0UuPNezaKDbJa',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Playa Lovegrass',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-12T17:27:07.153890',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Eragrostis pilosa var. perplexa',
#       'namewind': 'Eragrostis pilosa var. perplexa',
#       'scientificname': 'Eragrostis pilosa var. perplexa',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Plants',
#       'tsn': '527901'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbJj',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Short-ray Fleabane',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-06T16:08:05.070318',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Erigeron lonchophyllus',
#       'namewind': 'Erigeron lonchophyllus',
#       'scientificname': 'Erigeron lonchophyllus',
#       'sgcn2005': 1,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Plants',
#       'tsn': '35897'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbJn',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Early Blue-top Fleabane',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T13:50:03.489231',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Erigeron vetensis',
#       'namewind': 'Erigeron vetensis',
#       'scientificname': 'Erigeron vetensis',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Plants',
#       'tsn': '35970'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbJp',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Nodding Wild-buckwheat',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T13:50:04.514606',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Eriogonum cernuum',
#       'namewind': 'Eriogonum cernuum',
#       'scientificname': 'Eriogonum cernuum',
#       'sgcn2005': 1,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Vascular Plants',
#       'tsn': '21090'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbJx',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Wild Indigo Duskywing',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T13:50:05.413323',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Erynnis baptisiae',
#       'namewind': 'Erynnis baptisiae',
#       'scientificname': 'Erynnis baptisiae',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Insects',
#       'tsn': '706739'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbJ1',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Mottled Duskywing',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T16:08:15.158256',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Erynnis martialis',
#       'namewind': 'Erynnis martialis',
#       'scientificname': 'Erynnis martialis',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Insects',
#       'tsn': '706746'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbJ2',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Hairy Duskywing',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T14:01:02.966580',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Erynnis persius fredericki',
#       'namewind': 'Erynnis persius fredericki',
#       'scientificname': 'Erynnis persius fredericki',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Insects',
#       'tsn': '707397'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbJ6',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Johnny Darter',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T14:15:18.908764',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Etheostoma nigrum',
#       'namewind': 'Etheostoma nigrum',
#       'scientificname': 'Etheostoma nigrum',
#       'sgcn2005': 1,
#       'sgcn2015': 0,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Fish',
#       'tsn': '168369'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbKA',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Dotted Blue',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-06T16:08:45.369343',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Euphilotes ancilla',
#       'namewind': 'Euphilotes ancilla',
#       'scientificname': 'Euphilotes ancilla',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Insects',
#       'tsn': '777912'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbKC',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Eastern Toothed Spurge',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-12T18:59:09.519276',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Euphorbia dentata',
#       'namewind': 'Euphorbia dentata',
#       'scientificname': 'Euphorbia dentata',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Plants',
#       'tsn': '502535'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbKN',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Western Tailed Blue',
#       'discoveredtsn': '778219',
#       'itis_cachedate': '2017-05-12T18:39:59.506321',
#       'itismatchmethod': 'AcceptedTSNFollow',
#       'itismatchmethod_searchstring': 'Everes amyntula',
#       'namewind': 'Cupido amyntula amyntula',
#       'scientificname': 'Everes amyntula',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Insects',
#       'tsn': '778809'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbKQ',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Peregrine Falcon',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T13:31:50.590668',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Falco peregrinus',
#       'namewind': 'Falco peregrinus',
#       'scientificname': 'Falco peregrinus',
#       'sgcn2005': 1,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Birds',
#       'tsn': '175604'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbKR',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Mountain Lion',
#       'discoveredtsn': '180587',
#       'itis_cachedate': '2017-05-12T18:25:26.113394',
#       'itismatchmethod': 'AcceptedTSNFollow',
#       'itismatchmethod_searchstring': 'Felis concolor',
#       'namewind': 'Puma concolor',
#       'scientificname': 'Felis concolor',
#       'sgcn2005': 1,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Mammals',
#       'tsn': '552479'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbKS',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Harvester',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T15:05:34.700017',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Feniseca tarquinius',
#       'namewind': 'Feniseca tarquinius',
#       'scientificname': 'Feniseca tarquinius',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Insects',
#       'tsn': '777787'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbKd',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Showy Orchid',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T15:35:14.316992',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Galearis spectabilis',
#       'namewind': 'Galearis spectabilis',
#       'scientificname': 'Galearis spectabilis',
#       'sgcn2005': 1,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Plants',
#       'tsn': '43591'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbKn',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Rough Avens',
#       'discoveredtsn': '195823',
#       'itis_cachedate': '2017-05-12T18:40:02.249015',
#       'itismatchmethod': 'AcceptedTSNFollow',
#       'itismatchmethod_searchstring': 'Geum laciniatum var. trichocarpum',
#       'namewind': 'Geum laciniatum',
#       'scientificname': 'Geum laciniatum var. trichocarpum',
#       'sgcn2005': 1,
#       'sgcn2015': 0,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Vascular Plants',
#       'tsn': '24652'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbKp',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Southern Flying Squirrel',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T13:52:18.709080',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Glaucomys volans',
#       'namewind': 'Glaucomys volans',
#       'scientificname': 'Glaucomys volans',
#       'sgcn2005': 1,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Mammals',
#       'tsn': '180170'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbKv',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Elusive Clubtail',
#       'discoveredtsn': '101687',
#       'itis_cachedate': '2017-05-12T18:46:22.981083',
#       'itismatchmethod': 'AcceptedTSNFollow',
#       'itismatchmethod_searchstring': 'Gomphus notatus',
#       'namewind': 'Stylurus notatus',
#       'scientificname': 'Gomphus notatus',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Insects',
#       'tsn': '593022'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbK0',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Perennial Gumweed',
#       'discoveredtsn': '514261',
#       'itis_cachedate': '2017-05-12T18:30:35.498632',
#       'itismatchmethod': 'AcceptedTSNFollow',
#       'itismatchmethod_searchstring': 'Grindelia perennis',
#       'namewind': 'Grindelia hirsutula',
#       'scientificname': 'Grindelia perennis',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Plants',
#       'tsn': '37451'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbK5',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Bald Eagle',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-06T16:10:03.690759',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Haliaeetus leucocephalus',
#       'namewind': 'Haliaeetus leucocephalus',
#       'scientificname': 'Haliaeetus leucocephalus',
#       'sgcn2005': 1,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Birds',
#       'tsn': '175420'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbK9',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Seaside Heliotrope',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-12T17:44:20.363383',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Heliotropium curassavicum var. curassavicum',
#       'namewind': 'Heliotropium curassavicum var. curassavicum',
#       'scientificname': 'Heliotropium curassavicum var. curassavicum',
#       'sgcn2005': 1,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Plants',
#       'tsn': '528372'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbLA',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Common Branded Skipper',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T13:54:02.310711',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Hesperia colorado',
#       'namewind': 'Hesperia colorado',
#       'scientificname': 'Hesperia colorado',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Insects',
#       'tsn': '706616'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbLE',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Uncas Skipper',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T13:54:03.118284',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Hesperia uncas',
#       'namewind': 'Hesperia uncas',
#       'scientificname': 'Hesperia uncas',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Insects',
#       'tsn': '706629'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbLG',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Bouquet Mud-Plantsain',
#       'discoveredtsn': None,
#       'itis_cachedate': '2017-05-07T17:13:14.110369',
#       'itismatchmethod': 'ExactMatch',
#       'itismatchmethod_searchstring': 'Heteranthera multiflora',
#       'namewind': 'Heteranthera multiflora',
#       'scientificname': 'Heteranthera multiflora',
#       'sgcn2005': 1,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Plants',
#       'tsn': '502962'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'},
#    {'_id': 'AVxabwk0UuPNezaKDbLI',
#     '_index': 'bcb_sgcn_sgcn_statelists',
#     '_score': 3.840837,
#     '_source': {'properties': {'acceptedtsn': None,
#       'commonname': 'Camphor-weed',
#       'discoveredtsn': '37672',
#       'itis_cachedate': '2017-05-12T18:26:52.391706',
#       'itismatchmethod': 'AcceptedTSNFollow',
#       'itismatchmethod_searchstring': 'Heterotheca latifolia',
#       'namewind': 'Heterotheca subaxillaris ssp. latifolia',
#       'scientificname': 'Heterotheca latifolia',
#       'sgcn2005': 0,
#       'sgcn2015': 1,
#       'sgcn_state': 'Nebraska',
#       'taxonomicgroup': 'Plants',
#       'tsn': '780738'},
#      'type': 'Feature'},
#     '_type': 'sgcn_statelists'}],
#   'max_score': 3.840837,
#   'total': 945},
#  'timed_out': False,
#  'took': 1}

# %% [markdown]
# ## Aggregations (facets)
# The ES index for the state lists is set up to support aggregations on taxonomicgroup for faceted searching in the system. The aggregations are added to the query DSL using the following:
# ```json
# {
#   "aggs": {
#     "taxrank": {
#       "terms": {
#         "field": "properties.taxonomicgroup"
#       }
#     }
# }
# ```
# See the [ElasticSearch documentation](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-terms-aggregation.html) on aggregations for more details.

# %%
# Query for the specified state name and add in the aggregations
queryWithAggs = "https://gc2.mapcentia.com/api/v1/elasticsearch/search/bcb/sgcn/sgcn_statelists?q={%22query%22:{%22match%22:{%22properties.sgcn_state%22:%22"+stateName+"%22}},%22aggs%22:%20{%22taxgroup%22:%20{%22terms%22:%20{%22field%22:%20%22properties.taxonomicgroup%22}}}}"
rAggs = requests.get(queryWithAggs).json()

print ("Taxonomic Group")
for bucket in rAggs["aggregations"]["taxgroup"]["buckets"]:
    print (bucket["key"], bucket["doc_count"])
# Out:
# Taxonomic Group
# plants 572
# vascular 243
# insects 140
# birds 113
# mammals 36
# fish 33
# reptiles 28
# mollusks 12
# bivalves 6
# amphibians 4

# %% [markdown]
# ### Taxonomic Authority Check
#
# To derive the SGCN National List, the USGS processes the names submitted by states against lookup services from taxonomic authorities. The results of this check are recorded in the data and then used to build the sgcn_nationallist index that drives the web app and other uses. The sgcn_statelists view/index contains the necessary properties to show exactly what the matching process consisted of and resulted in.
#
# In the web app, this information has been shown as a set of "name changes" on a separate tab. This should change to provide a full report for the state by unique submitted name by using the information directly from the index for each record. This can be done with a similar device in the web app of showing a separate table, but it is essentially just an extension of several new properties onto the existing information.
#
# Definition of the properties:
#
# * itismatchmethod - One of four values describing the results of checking the species name against ITIS. In the sgcn_statelists ES index, this property can be used to aggregate the data, allowing for facets/filters on the 4 values.
#     * ExactMatch - Found an exact match of one taxon using the name string shown in itismatchmethod_searchstring
#     * FuzzyMatch - Found a fuzzy match using the ITIS Solr service for a single taxon using the name string in itismatchmethod_searchstring
#     * AcceptedTSNFollow - Found a match using the name string, but followed the accepted taxonomic because the discovered name was changed in ITIS
#     * NotMatched - The provided name could not be matched at this time. Taxa with "NotMatched" values are implicitly not on the National List, whereas taxa in any of the other three categories of itismatchmethod are on the National List.
# * itismatchmethod_searchstring - The exact name string used to search against ITIS. When this string and the scientificname are not exactly the same, it indicates that one or more rules to clean up the names for processing was triggered and applied in the process. These rules are defined in the "stringCleaning" function of the ITIS processing script and should probably be documented somewhere for the SWAP web app to pull from.
# * itis_cachedate - The exact date/time that the search was conducted for the record.
# * namewind - The name with indicators for the accepted taxon as provided by ITIS. This is the name that is shown in the National List as opposed to the submitted name from the state.
# * tsn - The ITIS Taxonomic Serial Number (TSN) for the valid taxonomy. This can be put together with one or another of the ITIS URLs to provide a meaningful link for users. For instance, human-readable web pages in ITIS currently look like https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=983598. The presence of a tsn value in a state lists implicitly indicates that the taxon is on the "National List."
# * discoveredtsn - The ITIS TSN at the point of discovery where an accepted TSN was followed to bring back the currently taxonomy for the record. This can also be linked to an ITIS web page.
#
# Abby will need to weigh in on exactly how to present this information. We may want to do things like turn the somewhat cryptic values into better descriptors and provide some derivation on the above explanation for the web site.

# %%
# Aggregations query on the itismatchmethod showing an overview of the results for a given state
q_itismatchmethodaggs = "https://gc2.mapcentia.com/api/v1/elasticsearch/search/bcb/sgcn/sgcn_statelists?q={%22query%22:{%22match%22:{%22properties.sgcn_state%22:%22"+stateName+"%22}},%22aggs%22:%20{%22itismatchmethod%22:%20{%22terms%22:%20{%22field%22:%20%22properties.itismatchmethod%22}}}}"
r_itismatchmethodaggs = requests.get(q_itismatchmethodaggs).json()

print ("ITIS Match Method")
for bucket in r_itismatchmethodaggs["aggregations"]["itismatchmethod"]["buckets"]:
    print (bucket["key"], bucket["doc_count"])
# Out:
# ITIS Match Method
# exactmatch 788
# acceptedtsnfollow 107
# notmatched 31
# fuzzymatch 19
