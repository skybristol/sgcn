# %% [markdown]
# This process registeres unique species names from the SGCN source data into the Taxonomic Information Registry. The process is all based on pulling unique species names that are then examined via TIR processes to find matches with taxonomic authorities. Those decisions on taxonomic matching are used to create a nationally synthesized list of taxa that states have listed as Species of Greatest Conservation Need.
#
# Registration consists of a set of key/value pairs that are inserted into the registration property of the TIR table. An hstore column in PostgreSQL of key/value pairs is used in order to accommodate different registration vectors having varying attributes. Every registration has the following:
# * source - Logical name specifying the source of the registration ("SGCN" in this case)
# * registrationDate - Date/time stamp of the registration
#
# Most TIR registrations will have a "scientificname" property containing the name string used as a primary identifier. Some TIR registrations will have other identifiers that come from source material.
#
# SGCN registrations include a list of common names and taxonomic groups supplied by the state and pulled together with an array_agg function and a DISTINCT operator to create a list of unique values in a string. These values can then be reasoned on in TIR processing.

# %%
import requests,datetime,configparser
from IPython.display import display

# %%
# Get API keys and any other config details from a file that is external to the code.
config = configparser.RawConfigParser()
config.read_file(open(r'../config/stuff.py'))

dt = datetime.datetime.utcnow().isoformat()

# %%
# Build base URL with API key using input from the external config.
def getBaseURL():
    gc2APIKey = config.get('apiKeys','apiKey_GC2_BCB').replace('"','')
    apiBaseURL = "https://gc2.mapcentia.com/api/v1/sql/bcb?key="+gc2APIKey
    return apiBaseURL

# %%
# Basic function to insert registration info pairs into TIR
def idsToTIR(recordInfoPairs):
    # Build query string
    insertSQL = "INSERT INTO tir.tir2 (registration) VALUES ('"+recordInfoPairs+"')"
    # Execute query
    response = requests.get(getBaseURL()+"&q="+insertSQL).json()
    return response

# %%
q_sgcn = "SELECT scientificname_submitted scientificname, \
    array_to_string(array_agg(DISTINCT CASE WHEN commonname_submitted <> '' THEN commonname_submitted ELSE NULL END),',') commonnames, \
    array_to_string(array_agg(DISTINCT CASE WHEN taxonomicgroup_submitted <> '' THEN taxonomicgroup_submitted ELSE NULL END),',') taxonomicgroups \
    FROM sgcn.sgcn \
    WHERE scientificname_submitted <> '' \
    GROUP BY scientificname_submitted"
r_sgcn = requests.get(getBaseURL()+"&q="+q_sgcn).json()

# %%
recordCount = 0
for sgcn in r_sgcn['features']:
    recordInfoPairs = '"registrationDate" => "'+dt+'"'
    recordInfoPairs = recordInfoPairs+',"source"=>"SGCN"'
    recordInfoPairs = recordInfoPairs+',"scientificname"=>"'+sgcn['properties']['scientificname'].replace("\'","''")+'"'
    recordInfoPairs = recordInfoPairs+',"commonnames"=>"'+sgcn['properties']['commonnames'].replace("\'","''")+'"'
    recordInfoPairs = recordInfoPairs+',"taxonomicgroups"=>"'+sgcn['properties']['taxonomicgroups']+'"'
    recordCount = recordCount + 1
    try:
        print (recordInfoPairs)
#        print (sgcnRecord['properties']['scientificname_submitted'], idsToTIR(recordInfoPairs))
        numProcessed = numProcessed + 1
    except:
        print ("Problem with: "+recordInfoPairs)
print ("Unique records processed: "+str(recordCount))
# Out:
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abacion tessalatum","commonnames"=>"A millipede","taxonomicgroups"=>"Myriapods,Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abacion wilhelminae","commonnames"=>"millipede,Millipede","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abagrotis barnesi","commonnames"=>"A noctuid moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abagrotis brunneipennis","commonnames"=>"Yankee Dart","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abagrotis crumbi benjamini","commonnames"=>"Benjamin''s abagrotis","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abagrotis nefascia","commonnames"=>"Coastal Heathland Cutworm","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abagrotis nefascia benjamini","commonnames"=>"Coastal heathland cutworm,Coastal Heathland Cutworm","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abagrotis orbis","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Ablautus schlingeri","commonnames"=>"Oso Flaco Robber Fly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abra aequalis","commonnames"=>"Atlantic abra","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abronia ameliae","commonnames"=>"Amelia''s Sand-verbena","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abronia macrocarpa","commonnames"=>"Large-fruited sand-verbena","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abronia umbellata ssp. breviflora","commonnames"=>"pink sand-verbena","taxonomicgroups"=>"Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abronia umbellata var. breviflora","commonnames"=>"Pink Sandverbena","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abudefduf saxatilis","commonnames"=>"Sergeant Major","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abudefduf taurus","commonnames"=>"Night Sergeant","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abutilon eremitopetalum","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abutilon menziesii","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Abutilon sandwicense","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acabaria bicolor","commonnames"=>"bicolor gorgonian,Bicolor Gorgonian","taxonomicgroups"=>"Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acacia koa","commonnames"=>"koa,Koa","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acacia koaia","commonnames"=>"koaia, koa oha,Koaiʻa, Koa ʻOhā","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acaena exigua","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acalypha deamii","commonnames"=>"Large Seeded Mercury","taxonomicgroups"=>"Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acalypha gracilens","commonnames"=>"slender copperleaf,Slender Copperleaf","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acalypha ostryifolia","commonnames"=>"Rough-pod Copperleaf","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acalypta lillianus","commonnames"=>"lace bug,Lace Bug","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acalypta susanae","commonnames"=>"lace bug,Lace Bug","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthametropus pecatonica","commonnames"=>""A Mayfly",Pecatonica River mayfly,Pecatonica River Mayfly","taxonomicgroups"=>"Insect,Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acantharchus pomotis","commonnames"=>"mud sunfish,Mud sunfish,Mud Sunfish","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acantharcus pomotis","commonnames"=>"Mud sunfish","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthemblemaria aspera","commonnames"=>"Roughhead Blenny","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthemblemaria chaplini","commonnames"=>"Papillose Blenny","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthochiton viridis","commonnames"=>"green chiton, kuakulu,Green Chiton, Kuakulu","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthocybium solandri","commonnames"=>"Wahoo","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthocyclops columbiensis","commonnames"=>"A copepod","taxonomicgroups"=>"Crustaceans"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthocyclops Columbiensis","commonnames"=>"A Copepod","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthocyclops Villosipes","commonnames"=>"A Copepod","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthohaustorius intermedius","commonnames"=>""An amphipod",No common name","taxonomicgroups"=>"Crustaceans"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthohaustorius millsi","commonnames"=>""An amphipod",No common name","taxonomicgroups"=>"Crustaceans"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthohaustorius shoemakeri","commonnames"=>""An amphipod"","taxonomicgroups"=>"Crustaceans"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthostracion quadricornis","commonnames"=>"Scrawled Cowfish","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthuridae","commonnames"=>"Surgeonfish","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthurus bahianus","commonnames"=>"Ocean Surgeon","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthurus chirurgus","commonnames"=>"Doctorfish","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acanthurus coeruleus","commonnames"=>"Blue Tang","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acari","commonnames"=>"mites and ticks,Mites and Ticks","taxonomicgroups"=>"Arachnids"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acartia tonsa","commonnames"=>"No common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acaulon muticum var. muticum","commonnames"=>"A Moss","taxonomicgroups"=>"Bryophytes"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acaulon muticum var. rufescens","commonnames"=>"A Moss","taxonomicgroups"=>"Bryophytes"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Accipiter cooperii","commonnames"=>"Cooper''s hawk,Cooper''s Hawk","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Accipiter Cooperii","commonnames"=>"Cooper''s Hawk","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Accipiter gentilis","commonnames"=>"northern goshawk,Northern goshawk,Northern Goshawk","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Accipiter gentilis apache","commonnames"=>"Apache Northern Goshawk","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Accipiter gentilis atricapillus","commonnames"=>"Northern Goshawk","taxonomicgroups"=>"Bird,Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Accipiter gentilus","commonnames"=>"Northern Goshawk","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Accipiter gentilus atricapillus","commonnames"=>"Northern Goshawk","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Accipiter gentilus laingi","commonnames"=>"Queen Charlotte Northern Goshawk","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Accipiter striatus","commonnames"=>"sharp-shinned hawk,Sharp-shinned hawk,Sharp-shinned Hawk,Sharp-Shinned Hawk","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Accipiter striatus venator","commonnames"=>"Sharp Shinned Hawk","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acella haldemani","commonnames"=>"spindle lymnaea,Spindle lymnaea,Spindle Lymnaea","taxonomicgroups"=>"Gastropods,Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acentrella feropagus","commonnames"=>"A mayfly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acentrella parvula","commonnames"=>"A Mayfly,Small Minnow Mayfly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acer glabrum","commonnames"=>"Rocky Mountain Maple","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aceria chrondriphora","commonnames"=>"Ashleaf gall mite","taxonomicgroups"=>"Mite"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aceria fraxiniflora","commonnames"=>"Ash flowergall mite","taxonomicgroups"=>"Mite"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aceria fraxinivorus","commonnames"=>"Ash key gall mite","taxonomicgroups"=>"Mite"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acerpenna pygmaea","commonnames"=>"Tiny Blue-Winged Olive","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acer spicatum","commonnames"=>"Mountain Maple","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acetes americanus","commonnames"=>"No common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acetropis americana","commonnames"=>"American grass bug","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achalarus lyciades","commonnames"=>"Hoary Edge,The Hoary Edge Skipper","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella apexfulva","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella bulimoides","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella byronii/ decepiens","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella concavospira","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella fulgens","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella fuscobasis","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella lila","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella livida","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella mustelina","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella pupukanioe","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella sowerbyana","commonnames"=>"O‘ahu Tree Snail","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achatinella spp.","commonnames"=>"O‘ahu Tree Snail,Oahu tree snails","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achelia sawayai","commonnames"=>"No common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achnatherum curvifolium","commonnames"=>"Guadalupe needlegrass","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achyranthes mutica","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Achyranthes splendens var. rotundata","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acilius mediatus","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acipenser brevirostrum","commonnames"=>"Shortnosed Sturgeon,shortnose sturgeon,Shortnose sturgeon,Shortnose Sturgeon","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acipenser fulvescens","commonnames"=>"lake sturgeon,Lake sturgeon,Lake Sturgeon","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acipenser medirostris","commonnames"=>"green sturgeon,Green sturgeon,Green Sturgeon,Green sturgeon (southern DPS)","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"ACIPENSER OXRINCHUS DESOTOI","commonnames"=>"GULF STURGEON","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acipenser oxyrhinchus desotoi","commonnames"=>"Gulf Sturgeon","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acipenser oxyrhynchus","commonnames"=>"Atlantic sturgeon,Atlantic Sturgeon","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acipenser oxyrinchus","commonnames"=>"Atlantic sturgeon,Atlantic Sturgeon","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acipenser oxyrinchus desotoi","commonnames"=>"Gulf of Mexico Sturgeon,Gulf Sturgeon","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acipenser oxyrinchus oxyrinchus","commonnames"=>"Atlantic Sturgeon","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acipenser transmontanus","commonnames"=>"white sturgeon,White Sturgeon,White Sturgeon (Kootenai River system),White Sturgeon (Snake River system)","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acipenser transmontanus pop.2","commonnames"=>"White sturgeon (Columbia River)","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acleisanthes acutifolia","commonnames"=>"Havard trumpets","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acleisanthes crassifolia","commonnames"=>"Texas trumpets","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acleisanthes wrightii","commonnames"=>"Wright''s trumpets","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aconitum uncinatum","commonnames"=>"Southern monkshood,Southern Monkshood","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acontia delecta","commonnames"=>"a noctuid moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acontia lactipennis","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acorus americanus","commonnames"=>"American Sweetflag,American Sweet-Flag","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acrididae","commonnames"=>"","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acris blanchardi","commonnames"=>"Blanchard''s cricket frog,Blanchard''s Cricket Frog,Blanchards Cricket Frog","taxonomicgroups"=>"Amphibians,Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acris crepitans","commonnames"=>"Blanchards Cricket Frog,Cricket Frog,Eastern cricket frog,Northern cricket frog,Northern Cricket Frog","taxonomicgroups"=>"Amphibian,Amphibians"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acris crepitans blanchardi","commonnames"=>"Blanchard''s cricket frog,Blanchards cricket frog,Blanchard''s Cricket Frog","taxonomicgroups"=>"Amphibians"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acris crepitans crepitans","commonnames"=>"Eastern Cricket Frog","taxonomicgroups"=>"Amphibians"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acris gryllus","commonnames"=>"Southern Cricket Frog","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acrocephalus familiaris kingi","commonnames"=>"Nihoa millerbird,Nihoa Millerbird","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acrocephalus luscinia","commonnames"=>"Nightingale Reed-warbler,Saipan Reed-warbler","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acrocephalus luscinia luscinia","commonnames"=>"Nightingale reed-warbler","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acrochaetium dotyi","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Algae"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acrolepiopsis leucoscia","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acrolophidae","commonnames"=>"","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acrolophitus nevadensis","commonnames"=>"Nevada Point-Headed Grasshopper","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acrolophitus pulchellus","commonnames"=>"Idaho Point-headed Grasshopper","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acrolophus pholeter","commonnames"=>"Gopher Tortoise Acrolophus Moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroloxus coloradensis","commonnames"=>"Rocky Mountain capshell,Rocky Mountain Capshell","taxonomicgroups"=>"Gastropods,Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acromycter alcocki","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroneuria arenosa","commonnames"=>"Eastern Stone","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroneuria arida","commonnames"=>"A stonefly,A Stonefly,Elegant Stone","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroneuria evoluta","commonnames"=>"A Stonefly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroneuria flinti","commonnames"=>"Manassas stonefly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroneuria internata","commonnames"=>"Lobed Stone","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroneuria kosztarabi","commonnames"=>"Kosztarab''s common stonefly,Virginia stonefly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroneuria lycorias","commonnames"=>"A Stonefly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroneuria ozarkensis","commonnames"=>"Ozark Stone,Ozark stonefly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroneuria petersi","commonnames"=>"A Stonefly","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acronicta albarufa","commonnames"=>"Albarufan Dagger Moth,Barrens dagger moth,Barrens Daggermoth,Barrens Dagger Moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acronicta connecta","commonnames"=>"a noctuid moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acronicta dolli","commonnames"=>"Doll''s Merolonche","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acronicta exilis","commonnames"=>"exiled dagger moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acronicta falcula","commonnames"=>"corylus dagger moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acronicta increta","commonnames"=>"a dagger moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acronicta lanceolaria","commonnames"=>"A noctuid moth,no common name","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acronicta lithospila","commonnames"=>"streaked dagger moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acronicta rubricoma","commonnames"=>"a dagger moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acronicta tritona","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora cervicornis","commonnames"=>"Staghorn Coral","taxonomicgroups"=>"Cnidarians,Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora cytherea","commonnames"=>"table coral,Table Coral","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora gemmifera","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora globiceps","commonnames"=>"Acropora globiceps Coral","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora humilis","commonnames"=>"finger staghorn coral,Finger Staghorn Coral","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora nasuta","commonnames"=>"branching staghorn coral,Branching Staghorn Coral","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora palmata","commonnames"=>"Elkhorn Coral","taxonomicgroups"=>"Cnidarians,Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora paniculata","commonnames"=>"fuzzy table coral,Fuzzy Table Coral","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora prolifera","commonnames"=>"Fused Staghorn Coral","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora retusa","commonnames"=>"Acropora retusa Coral","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acropora valida","commonnames"=>"bushy staghorn coral,Bushy Staghorn Coral","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acroporidae","commonnames"=>"","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actaea pachypoda","commonnames"=>"White Baneberry","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actaea racemosa","commonnames"=>"Black Cohosh","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acteocina canaliculata","commonnames"=>"Channeled barrel-bubble","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acteocina candei","commonnames"=>"No common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actinemys (Clemmys) marmorata","commonnames"=>"Western pond turtle","taxonomicgroups"=>"Reptiles"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actinemys marmorata","commonnames"=>"Western Pond Turtle","taxonomicgroups"=>"Reptiles"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actinemys marmorata marmorata","commonnames"=>"northwestern pond turtle","taxonomicgroups"=>"Reptiles"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actiniidae","commonnames"=>"","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actinocidaris thomasi","commonnames"=>"Thomas''s sea urchin,Thomas''s Sea Urchin","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actinonaias ligamenta","commonnames"=>"Mucket","taxonomicgroups"=>"Bivalves"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actinonaias ligamentina","commonnames"=>"Mucket,Mucket mussel","taxonomicgroups"=>"Bivalves,Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"ACTINONAIAS LIGAMENTINA","commonnames"=>"MUCKET","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actinonaias pectorosa","commonnames"=>"Pheasantshell","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actinopyga agassizii","commonnames"=>"Five-toothed Sea Cucumber, West Indian Sea Cucumber","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actinopyga mauritiana","commonnames"=>"Surf redfish","taxonomicgroups"=>"Echinoderms"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actitis hypoleucos","commonnames"=>"Common Sandpiper","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actitis macularia","commonnames"=>"spotted sandpiper,Spotted sandpiper,Spotted Sandpiper","taxonomicgroups"=>"Bird,Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Actitis macularius","commonnames"=>"Spotted sandpiper,Spotted Sandpiper","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acupalpus alternans","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acupalpus rectangulus","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Acyrtops beryllinus","commonnames"=>"Emerald Clingfish","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adalia bipunctata","commonnames"=>"Two-spotted lady beetle","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adelia vaseyi","commonnames"=>"Vasey''s adelia","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adella oplerella","commonnames"=>"Opler''s Longhorn Moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adelocosa anops","commonnames"=>"Kauai cave wolf spider,Kaua‘i Cave Wolf Spider","taxonomicgroups"=>"Arachnids"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adenophorus periens","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adetus n. sp. EGR 1","commonnames"=>"A longhorned beetle","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adetus sp. EGR 1","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adhemarius blanchardorum","commonnames"=>"Blanchard''s sphinx,no common name","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adiantum aleuticum","commonnames"=>"Aleutian maidenhair-fern,Aleutian Maidenhair-fern","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adiantum viridimontanum","commonnames"=>"Green Mountain maidenhair-fern,Green Mountain Maidenhair-fern","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adinia xenica","commonnames"=>"Diamond Killifish","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adlumia fungosa","commonnames"=>"Climbing Fumitory","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adocia tubifera","commonnames"=>"No common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adopaeoides prittwitzi","commonnames"=>"Sunrise Skipper","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adoxomyia albopilosa","commonnames"=>"Soldier Fly","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Adrityla cucullata","commonnames"=>"A Millipede","taxonomicgroups"=>"Myriapods"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aechmophorus clarkii","commonnames"=>"Clark''s grebe,Clark''s Grebe,Clark’s Grebe,Clarks Grebe","taxonomicgroups"=>"Bird,Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aechmophorus occidentalis","commonnames"=>"Western grebe,Western Grebe","taxonomicgroups"=>"Bird,Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aegalius acadicus","commonnames"=>"Northern Saw-whet Owl","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aegathoa oculata","commonnames"=>"No common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aegialia concinna","commonnames"=>"Ciervo Aegialian Scarab Beetle","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aegolius acadicus","commonnames"=>"Northern Saw-Whet,Northern saw-whet owl,Northern Saw-whet Owl,Northern Saw-Whet Owl","taxonomicgroups"=>"Bird,Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aegolius funereus","commonnames"=>"Boreal owl,Boreal Owl","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aenaria interpres","commonnames"=>"Ruddy Turnstone","taxonomicgroups"=>"Bird"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeoloplides rotundipennis","commonnames"=>"Grasshopper","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aerodramus bartschi","commonnames"=>"Mariana Swiftlet","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aerodramus vanikorensis bartschi","commonnames"=>"Island swiftlet,Mariana Swiftlet","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeronautes saxatalis","commonnames"=>"White-throated swift,White-throated Swift,White-Throated Swift","taxonomicgroups"=>"Bird,Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeropedellus clavatus","commonnames"=>"Club-horned Grasshopper","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aesculus glabra","commonnames"=>"Ohio Buckeye","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aesculus glabra var. arguta","commonnames"=>"Ohio Buckeye,Western Buckeye","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aesculus parviflora","commonnames"=>"Small-flowered Buckeye","taxonomicgroups"=>"Plant"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna canadensis","commonnames"=>"Canada darner,Canada Darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna clepsydra","commonnames"=>"mottled darner,Mottled darner,Mottled Darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna constricta","commonnames"=>"Lance-tipped darner,Lance-tipped Darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna dugesi","commonnames"=>"Arroyo Darner","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna interrupta","commonnames"=>"Variable Darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna interrupta interrupta","commonnames"=>"Variable Darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna juncea","commonnames"=>"sedge darner,Sedge Darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna multicolor","commonnames"=>"Blue-eyed Darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna mutata","commonnames"=>"spatterdock darner,Spatterdock darner,Spatterdock Darner,Spring blue darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna sitchensis","commonnames"=>"zigzag darner,Zigzag Darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna subarctica","commonnames"=>"muskeg darner,subarctic darner,Subarctic darner,Subarctic Darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna tuberculifera","commonnames"=>"Back-tipped Darner,black-tipped darner,Black-tipped darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshna verticalis","commonnames"=>"green-striped darner,Green-striped darner,Green-striped Darner","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeshnidae","commonnames"=>"","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aethecerinus hornii","commonnames"=>"Horn''s Aethecerinus Long-horned Beetle","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aethia cristatella","commonnames"=>"Crested Auklet","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aethia pusilla","commonnames"=>"Least Auklet","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aethia pygmaea","commonnames"=>"Whiskered Auklet","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aethra edentata","commonnames"=>"flat elbow crab,Flat Elbow Crab","taxonomicgroups"=>"Crustaceans"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aetobatus narinari","commonnames"=>"Spotted Eagle Ray","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeverrillia armata","commonnames"=>"No common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aeverrillia setigera","commonnames"=>"No common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Aflexia rubranura","commonnames"=>"Red-tailed Leafhopper,Red-tailed Prairie Leafhopper,Red Tailed Prairie Leafhopper,redveined prairie leafhopper","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabetes acuductus","commonnames"=>"a hydrophylid beetle,A Water Scavenger Beetle","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus aeruginosus","commonnames"=>"A Predaceous Diving Beetle,no common name","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus bicolor","commonnames"=>"A Predaceous Diving Beetle","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus canadensis","commonnames"=>"A Predaceous Diving Beetle","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus confinis","commonnames"=>"A Predaceous Diving Beetle","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus confusus","commonnames"=>"A Predaceous Diving Beetle","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus discolor","commonnames"=>"A Predaceous Diving Beetle,no common name","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus disintegratus","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus gagates","commonnames"=>"A Predaceous Diving Beetle","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus immaturus","commonnames"=>"A Predaceous Diving Beetle,no common name","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus inscriptus","commonnames"=>"A Predaceous Diving Beetle","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus leptapsis","commonnames"=>"A Predaceous Diving Beetle,no common name","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agabus rumppi","commonnames"=>"Death Valley Agabus Diving Beetle","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis acuta","commonnames"=>"Sandplain Gerardia","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis aphylla","commonnames"=>"Coastal Plain False-foxglove","taxonomicgroups"=>"Plant"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis aspera","commonnames"=>"Rough false foxglove","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis auriculata","commonnames"=>"Auriculate False Foxglove,Eared False foxglove,Earleaf false foxglove,Earleaf Foxglove","taxonomicgroups"=>"Plant,Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis calycina","commonnames"=>"Leoncita false foxglove","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis densiflora","commonnames"=>"Osage Plains false foxglove","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis gattingeri","commonnames"=>"Round-stem False Foxglove","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis heterophylla","commonnames"=>"Prairie false foxglove,Prairie False Foxglove","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis maritima","commonnames"=>"Salt-marsh False-foxglove","taxonomicgroups"=>"Plant"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis navasotensis","commonnames"=>"Navasota false foxglove","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis purpurea","commonnames"=>"Purple false foxglove,Purple False Foxglove,Smooth False Foxglove","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis tenuifolia var. macrophylla","commonnames"=>"Narrow-leaf False Foxglove","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agalinis viridis","commonnames"=>"Green false foxglove,Green False Foxglove","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agallissus lepturoides (Chevrolat)","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agapema galbina","commonnames"=>"no common name,Tamaulipan Agapema","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agapema homogena","commonnames"=>"Rocky Mountain agapema,Rocky Mountain Agapema","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agapetus artesus","commonnames"=>"Artesian agapetus caddisfly,Artesian Agapetus Caddisfly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agapetus hessi","commonnames"=>"A Saddle Casemaker Caddisfly","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Agapetus iridis","commonnames"=>"Beloved Rainbow Caddisfly","taxonomicgroups"=>"Insects"
# ...
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Ylodes frontalis","commonnames"=>"a species of long-horned caddisfly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Yucca arkansana","commonnames"=>"Arkansas Yucca,Soft soapweed","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Yucca cernua","commonnames"=>"Nodding yucca","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Yucca glauca","commonnames"=>"Small Soapweed Yucca,Soapweed","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Yucca necopina","commonnames"=>"Glen Rose yucca","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Yugus arinus","commonnames"=>"Highlands springfly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zacoleus idahoensis","commonnames"=>"Sheathed Slug","taxonomicgroups"=>"Gastropods"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zaitzevia thermae","commonnames"=>"Warm Spring Zaitzevian Riffle Beetle","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale calycanthata","commonnames"=>"A Noctuid Moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale curema","commonnames"=>"A noctuid moth,Black-eyed Zale,no common name,Northeastern Pine Zale","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale largera","commonnames"=>"A noctuid moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale lunifera","commonnames"=>"Bold-based zale moth,Bold-based Zale Moth,Pine Barrens Zale","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale metata","commonnames"=>"a noctuid moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale obliqua","commonnames"=>"A noctuid moth,no common name,Oblique Zale,Oblique Zale Moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale perculta","commonnames"=>"Okefenokee Zale Moth","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale sp 1","commonnames"=>"pine barrens zale,Pine Barrens zale","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale sp. 1","commonnames"=>"Pine Barrens Zale","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale sp. 1 nr. lunifera","commonnames"=>"Pine Barrens Zale","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale sp. 1 nr. Lunifera","commonnames"=>"Pine barrens zale","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale squamularis","commonnames"=>"A noctuid moth,Gray-banded Zale","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zale submediana","commonnames"=>"a noctuid moth,A noctuid moth,A Noctuid Moth,A Zale Moth,gray spring zale,no common name","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zalieutes mcgintyi","commonnames"=>"Tricorn Batfish","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zanclognatha martha","commonnames"=>"no common name,pine barrens zanclognatha,Pine barrens zanclognatha,Pine Barrens Zanclognatha","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zanclognatha sp 1","commonnames"=>"no common name","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zannichellia palustris","commonnames"=>"horned pondweed,Horned Pondweed","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zannichellia palustris var. major","commonnames"=>"Horned Pondweed","taxonomicgroups"=>"Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zanthoxylum dipetalum var. tomentosum","commonnames"=>"kawau,Kāwaʻu","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zanthoxylum flavum","commonnames"=>"Satinwood","taxonomicgroups"=>"Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zanthoxylum hawaiiense","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zanthoxylum oahuense","commonnames"=>"no common name,No Common Name","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zanthoxylum parvum","commonnames"=>"Shinners'' tickle-tongue","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zanthoxylum spp.","commonnames"=>"ae, heae,Aʻe, Heaʻe","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zanthoxylum thomasianum","commonnames"=>"St. Thomas Prickly-ash","taxonomicgroups"=>"Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zaops ostreum","commonnames"=>"Oyster pea crab","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapada chila","commonnames"=>"(a stonefly),Smokies Forestfly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapada cordillera","commonnames"=>"A Stonefly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapada glacier","commonnames"=>"Western Glacier Stonefly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapada wahkeena","commonnames"=>"Wahkeena Falls flightless stonefly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zaprora silenus","commonnames"=>"prowfish","taxonomicgroups"=>"Fish"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapus hudsonius","commonnames"=>"meadow jumping mouse,Meadow Jumping Mouse,Meadow jumping mouse (both subspecies)","taxonomicgroups"=>"Mammals"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"ZAPUS HUDSONIUS","commonnames"=>"MEADOW JUMPING MOUSE","taxonomicgroups"=>"Mammals"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapus hudsonius campestris","commonnames"=>"Bear Lodge meadow jumping mouse","taxonomicgroups"=>"Mammals"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapus hudsonius luteus","commonnames"=>"New Mexican Jumping Mouse,New Mexico meadow jumping mouse,New Mexico Meadow Jumping Mouse","taxonomicgroups"=>"Mammal,Mammals"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapus hudsonius preblei","commonnames"=>"Prebles meadow jumping mouse","taxonomicgroups"=>"Mammals"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapus hudsonius prebleii","commonnames"=>"Preble’s Meadow Jumping Mouse","taxonomicgroups"=>"Mammals"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapus princeps","commonnames"=>"western jumping mouse","taxonomicgroups"=>"Mammals"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zapus trinotatus orarius","commonnames"=>"Point Reyes Jumping Mouse","taxonomicgroups"=>"Mammals"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zealeuctra narfi","commonnames"=>"A Rolled-winged Winter Stonefly","taxonomicgroups"=>"Insects"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zealeuctra wachita","commonnames"=>"Ouachita Needlefly","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zelotes hentzi","commonnames"=>"Hentz''s Zelotes","taxonomicgroups"=>"Arachnids"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zeltnera exaltata","commonnames"=>"Desert Centaury","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zenaida asiatica","commonnames"=>"White-winged Dove","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zenaida aurita","commonnames"=>"Zenaida Dove","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zenaida macroura","commonnames"=>"Mourning dove,Mourning Dove","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zephyranthes jonesii","commonnames"=>"Jones''s rainlilly","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zephyranthes refugiensis","commonnames"=>"Refugio rainlily","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zephyranthes simpsonii","commonnames"=>"Rain Lily","taxonomicgroups"=>"Plant"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zephyranthes smallii","commonnames"=>"Small''s rainlilly","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zephyranthes traubii","commonnames"=>"Traub''s rainlilly","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zigadenus elegans ssp. glaucus","commonnames"=>"White Camas","taxonomicgroups"=>"Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zigadenus nuttallii","commonnames"=>"Death camas,Death Camas","taxonomicgroups"=>"Plants,Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Ziphius cavirostris","commonnames"=>"Cuvier''s beaked whale,Cuvier''s Beaked Whale,Cuvier’s Beaked Whale,Goose-beaked whale","taxonomicgroups"=>"Mammals"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zirfaea crispata","commonnames"=>"Atlantic Great Piddock","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zizania palustris var. interior","commonnames"=>"Interior Wild-rice,Interior Wild Rice","taxonomicgroups"=>"Vascular Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zizania texana","commonnames"=>"Texas wild rice,Texas wild-rice","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zoanthus kealakekuaensi","commonnames"=>"Green Mat Zoanthid","taxonomicgroups"=>"Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zoanthus kealakekuaensis","commonnames"=>"green mat zoanthid","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zoanthus pulchellus","commonnames"=>"Green Sea Mat","taxonomicgroups"=>"Cnidarians"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zomaria interuptolineana","commonnames"=>"no common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zonitoides arboreus","commonnames"=>"Quick Gloss","taxonomicgroups"=>"Invertebrate"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zonitoides lateumbilicatus","commonnames"=>"Striate Gloss","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zonitoides limatulus","commonnames"=>"dull gloss,Dull Gloss","taxonomicgroups"=>"Gastropods,Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zonitoides nitidus","commonnames"=>"black gloss,Black Gloss","taxonomicgroups"=>"Gastropods,Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zonitoides patuloides","commonnames"=>"Appalachian Gloss","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zonotrichia albicollis","commonnames"=>"White-throated sparrow,White-throated Sparrow","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zonotrichia atricapilla","commonnames"=>"Golden-crowned Sparrow","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zonotrichia leucophrys","commonnames"=>"White-crowned Sparrow","taxonomicgroups"=>"Bird,Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zonotrichia querula","commonnames"=>"Harris'' sparrow,Harris'' Sparrow,Harris''s sparrow,Harris''s Sparrow,Harriss Sparrow","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zoobotryon verticillatum","commonnames"=>"No common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zoogenetes harpa","commonnames"=>"Boreal Top","taxonomicgroups"=>"Mollusks"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zosteractis interminata","commonnames"=>"a millipede,Zosteractis cave millipede,Zosteractis Cave Millipede","taxonomicgroups"=>"Myriapods,Other Invertebrates"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zostera marina","commonnames"=>"Native Eelgrass","taxonomicgroups"=>"Plants"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zosterops conspicillatus saypani","commonnames"=>"Saipan Bridled White-eye","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zosterops rotensis","commonnames"=>"Rota Bridled White-eye,Rota White-eye","taxonomicgroups"=>"Birds"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zygeupolia rubens","commonnames"=>"No common name","taxonomicgroups"=>""
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zygodon apiculatus","commonnames"=>"A Moss","taxonomicgroups"=>"Bryophytes"
# "registrationDate" => "2017-05-26T16:20:01.045624","source"=>"SGCN","scientificname"=>"Zygonemertes virescens","commonnames"=>"No common name","taxonomicgroups"=>""
# Unique records processed: 17429
