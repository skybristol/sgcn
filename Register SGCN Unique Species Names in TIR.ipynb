# %% [markdown]
# This process registeres unique species names from the SGCN source data into the Taxonomic Information Registry. The process is all based on pulling unique species names that are then examined via TIR processes to find matches with taxonomic authorities. Those decisions on taxonomic matching are used to create a nationally synthesized list of taxa that states have listed as Species of Greatest Conservation Need.
#
# Registration consists of a set of key/value pairs that are inserted into the registration property of the TIR table. An hstore column in PostgreSQL of key/value pairs is used in order to accommodate different registration vectors having varying attributes. Every registration has the following:
# * source - Logical name specifying the source of the registration ("SGCN" in this case)
# * registrationDate - Date/time stamp of the registration
#
# Most TIR registrations will have a "scientificname" property containing the name string used as a primary identifier. Some TIR registrations will have other identifiers that come from source material.
#
# SGCN registrations include a list of common names and taxonomic groups supplied by the state and pulled together with an array_agg function and a DISTINCT operator to create a list of unique values in a string. These values can then be reasoned on in TIR processing. The code to register names in the TIR from the SGCN table could operate at any time there are new names showing up in the SGCN, but we might miss some of the aggregated common names when new state data is processed. To deal with this, we could set up a process to periodically check the SGCN records for new instances of a given name and reaggregate common names and taxonomic groups.

# %%
# %reload_ext autoreload

import requests,datetime
from IPython.display import display
from bis import tir
from bis2 import gc2

# %% [markdown]
# ### Get data to process
#
# This script gathers all of the unique taxonomic names (scientificname_submitted) from the SGCN data and registers them with the Taxonomic Information Registry. The query checks to make sure the taxon name is not already registered in the TIR.

# %%
q_sgcn = "SELECT scientificname_submitted scientificname, \
    array_to_string(array_agg(DISTINCT CASE WHEN commonname_submitted <> '' THEN commonname_submitted ELSE NULL END),',') commonnames, \
    array_to_string(array_agg(DISTINCT CASE WHEN taxonomicgroup_submitted <> '' THEN taxonomicgroup_submitted ELSE NULL END),',') taxonomicgroups \
    FROM sgcn.sgcn \
    WHERE scientificname_submitted <> '' \
    AND scientificname_submitted NOT IN (\
        SELECT registration->'scientificname' AS scientificname_submitted \
        FROM tir.tir \
        WHERE registration->'Source' = 'SGCN' \
    ) \
    GROUP BY scientificname_submitted"
r_sgcn = requests.get(gc2.sqlAPI("DataDistillery","BCB")+"&q="+q_sgcn).json()

# %% [markdown]
# ### Iterate over the data and process to TIR
#
# This block iterates over the unique species returned, packages up the data for the registration, and inserts them into the TIR table. It requires the following:
#
# * TIR table set up in the appropriate GC2-basede data schema
# * Registration field in the TIR table using the hstore data type
# * gc2 module from the BIS2 package (connection info for the API)
# * tir module from the BIS package (function to insert registration info)

# %%
recordCount = 0

for sgcn in r_sgcn['features']:
    recordInfoPairs = '"registrationDate" => "'+datetime.datetime.utcnow().isoformat()+'"'

    # Set source to indicate data coming from the SGCN system
    recordInfoPairs = recordInfoPairs+',"source"=>"SGCN"'

    # Set properties to configure taxonomic lookup rules
    recordInfoPairs = recordInfoPairs+',"taxonomicLookupProperty"=>"scientificname"'
    recordInfoPairs = recordInfoPairs+',"followTaxonomy"=>"true"'

    # Set the scientific name string - a common point of registration into the TIR (was formerly "SGCN_ScientificName_Submitted")
    recordInfoPairs = recordInfoPairs+',"scientificname"=>"'+sgcn['properties']['scientificname'].replace("\'","''")+'"'

    # Set a list of the unique common names that are associated with the scientific name
    recordInfoPairs = recordInfoPairs+',"commonnames"=>"'+sgcn['properties']['commonnames'].replace("\'","''")+'"'

    # Set a list of the unique taxonomic groups (something specific to the SGCN) that are associated with the scientific name
    recordInfoPairs = recordInfoPairs+',"taxonomicgroups"=>"'+sgcn['properties']['taxonomicgroups']+'"'

    try:
        print (sgcn['properties']['scientificname'], tir.tirRegistration(gc2.sqlAPI("DataDistillery","BCB"),recordInfoPairs))
        recordCount = recordCount + 1
    except Exception as e:
        print (e)

print ("Unique records processed: "+str(recordCount))
# Out:
# Accipiter gentilis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Accipiter gentilis atricapillus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.072}
# Acentrella parvula {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Acerpenna pygmaea {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Acris blanchardi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Acroloxus coloradensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Aechmophorus clarkii {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aechmophorus occidentalis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aegolius acadicus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Aegolius funereus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aeronautes saxatalis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.068}
# Agapema homogena {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Agosia chrysogaster {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Aimophila cassinii {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aix sponsa {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Amazilia violiceps {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Amblyderus werneri {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Ambystoma mavortium nebulosum {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Ambystoma mavortium stebbinsi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.07}
# Ametropus neavei {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.068}
# Ammodramus bairdii {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Ammodramus savannarum {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Ammodramus savannarum ammolegus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Ammodramus savannarum perpallidus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Ammospermophilus harrisii {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Ammospermophilus leucurus tersus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.071}
# Amphispiza belli {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Amphispiza quinquestriata {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Anaxyrus boreas boreas {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Anaxyrus debilis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Anisota oslari {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Anodonta californiensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Anodontoides ferussacianus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Anthus rubescens {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Anthus spragueii {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Antilocapra americana americana {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Antilocapra americana sonoriensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Aphelocoma californica {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aphelocoma ultramarina {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.071}
# Apobaetis etowah {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aquila chrysaetos {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Ardea alba {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Argia alberta {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Arsapnia [=Capnia] arapahoe {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Artemia franciscana {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Ashmunella chiricahuana {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Ashmunella ferrissi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Ashmunella levettei {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Ashmunella mogollonensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Ashmunella pilsbryana {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Ashmunella proxima {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Asio flammeus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Asio otus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.068}
# Aspidoscelis arizonae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aspidoscelis burti {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aspidoscelis exsanguis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aspidoscelis flagellicauda {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Aspidoscelis neotesselata {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aspidoscelis pai {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Aspidoscelis xanthonota {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Athene cunicularia {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Athene cunicularia hypugaea {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Atrytone arogos {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Baeolophus ridgwayi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.078}
# Baeolophus wollweberi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Baetis brunneicolor {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Bartramia longicauda {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Bison bison {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Boloria improba acrocnema {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.073}
# Bombus fervidus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Bombus fraternus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Bombus morrisoni {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Bombus occidentalis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Bombus pensylvanicus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.068}
# Bombus suckleyi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.068}
# Botaurus lentiginosus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Brachylagus idahoensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.069}
# Branchinecta coloradensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Branchinecta kaibabensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Branchinecta lindahli {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Branchinecta packardi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Bucephala islandica {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Bufo alvarius {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Bufo microscaphus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Bufo retiformis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Buteogallus anthracinus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Buteo regalis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.07}
# Buteo swainsoni {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Calamospiza melanocorys {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Calcarius ornatus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.07}
# Callipepla squamata {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Callophrys comstocki {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Callophrys mcfarlandi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Callophrys mossii schryveri {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.07}
# Calopteryx aequabilis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Calopteryx maculata {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Calypte costae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.068}
# Camelobaetidius warreni {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Campostoma ornatum {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Canis lupus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Canis lupus baileyi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Capnia nelsoni {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Caprimulgus arizonae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Caprimulgus ridgwayi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Cardellina rubrifrons {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Castor canadensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Catharus fuscescens {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Catharus ustulatus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Catinella avara {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Catinella vermeta {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.068}
# Catostomus bernardini {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Catostomus clarki {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Catostomus discobolus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.072}
# Catostomus discobolus yarrowi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Catostomus insignis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Catostomus latipinnis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Catostomus playtrhynchus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Catostomus plebeius {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Catostomus sp. {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Celastrina humulus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Centrocercus minimus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Centrocercus urophasianus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Chaenaxis tuba {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.069}
# Chaetodipus formosus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Chaetodipus intermedius {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Charadrius alexandrinus nivosus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Charadrius melodus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Charadrius montanus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Chilomeniscus stramineus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Chionactis occipitalis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Chionactis occipitalis klauberi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Chionactis palarostris {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Chlidonias niger {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Choeronycteris mexicana {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Chordeiles minor {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Chrosomus eos {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Chrosomus erythrogaster {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Chrysemys picta {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cicindela theatina {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cinclus mexicanus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cionella lubrica {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Circus cyaneus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cistothorus palustris {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Clethrionomys gapperi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Coccothraustes vespertinus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Coccyzus americanus occidentalis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Colaptes chrysoides {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Colinus virginianus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.072}
# Colinus virginianus ridgwayi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Coloradia luski {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Coluber constrictor mormon {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.07}
# Columella columella {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Conepatus leuconotus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Conepatus leuconotus leuconotus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Contopus cooperi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Contopus pertinax {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cordulegaster dorsalis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Corynorhinus townsendii pallescens {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Couesius plumbeus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Craugastor augusti {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.071}
# Crotalus cerberus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Crotalus lepidus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Crotalus oreganus concolor {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Crotalus pricei {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Crotalus tigris {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.073}
# Crotalus willardi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Crotalus willardi obscurus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Crotaphytus nebrius {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cynanthus latirostris {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cynomys gunnisoni {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cynomys leucurus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cynomys ludovicianus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cyprinella formosa {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.107}
# Cyprinodon eremus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.069}
# Cyprinodon macularius {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Cypseloides niger {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Cyrtonyx montezumae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.094}
# Cyzicus mexicanus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Cyzicus setosa {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Danaus plexippus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Dendragapus obscurus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Dendrocygna autumnalis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Dendroica graciae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Dendroica nigrescens {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Dendroica petechia {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.07}
# Deroceras laeve {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Dipodomys microps celsus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Dipodomys microps leucotis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0
'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Junco phaeonotus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Kinosternon arizonense {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Kinosternon flavescens {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# ...
# Sonorella papagorum {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.069}
# Sonorella parva {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Sonorella pedregosensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Sonorella reederi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.072}
# Sonorella rinconensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.069}
# Sonorella rosemontensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Sonorella russelli {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Sonorella sabinoensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Sonorella santaritana {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Sonorella simmonsi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Sonorella sitiens {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Sonorella superstitionis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Sonorella tortillita {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Sonorella tryoniana {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Sonorella vespertina {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Sonorella virilis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Sonorella walkeri {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.07}
# Sonorella waltoni {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Sonorella xanthenes {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Sorex arizonae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Sorex hoyi montanus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Sorex merriami {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Sorex nanus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Sorex palustris {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Sorex preblei {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Spea intermontana {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Spermophilus lateralis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Spermophilus spilosoma {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Spermophilus tridecemlineatus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.071}
# Sphyrapicus nuchalis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Sphyrapicus thyroideus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Spilogale gracilis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Spizella atrogularis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Spizella breweri {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Sterna antillarum {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.069}
# Sternula antillarum browni {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Streptocephalus dorothae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Streptocephalus mackini {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Streptocephalus sealii {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Streptocephalus texanus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Strix occidentalis lucida {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.08}
# Sturnella magna {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Stygobromus arizonensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Succinea grosvenori {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Succinea luteola {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Sylvilagus nuttallii grangeri {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Sylvilagus nuttallii pinetis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Tadarida brasiliensis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Tamias cinereicollis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Tamiasciurus hudsonicus grahamens {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.07}
# Tamias minimus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.071}
# Tamias quadrivittatus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Tamias umbrinus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.068}
# Tantilla horbartsmithi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Tantilla wilcoxi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Tantilla yaquia {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Terrapene ornata {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Thamnocephalus mexicanus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Thamnocephalus platyurus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Thamnophis cyrtopsis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Thamnophis eques megalops {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Thamnophis rufipunctatus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.07}
# Thamnophis sirtalis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Thomomys bottae rubidus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Thomomys bottae subsimilis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Thomomys talpoides {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.068}
# Thomomys umbrinus intermedius {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Thysanophora hornii {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.069}
# Tiaroga cobitis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Toxostoma bendirei {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Toxostoma lecontei {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Triops longicaudatus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Triops newberryi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Troglodytes pacificus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Trogon elegans {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Tryonia gilae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Tryonia quitobaquitae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Tympanuchus cupido {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Tympanuchus pallidicinctus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Tympanuchus phasianellus columbianus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Tympanuchus phasianellus jamesii {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.074}
# Tyrannus crassirostris {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Uma rufopunctata {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Uma scoparia {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Uniomerus tetralasmus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Ursus arctos {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Vallonia cyclophorella {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Vallonia perspectiva {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Valvata humeralis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Vertigo berryi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Vireo bellii arizonae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Vireo vicinior {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.069}
# Vitrina pellucida alaskana {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Vulpes macrotis {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Vulpes velox {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Vulpes vulpes {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Xantusia arizonae {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Xantusia bezyi {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Xyrauchen texanus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Zapus hudsonius luteus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.066}
# Zapus hudsonius preblei {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.065}
# Zonitoides arboreus {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.067}
# Zonotrichia leucophrys {'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'success': True, 'affected_rows': 1, '_execution_time': 0.064}
# Unique records processed: 688
