# %% [markdown]
# This process registeres unique species names from the SGCN source data into the Taxonomic Information Registry. The process is all based on pulling unique species names that are then examined via TIR processes to find matches with taxonomic authorities. Those decisions on taxonomic matching are used to create a nationally synthesized list of taxa that states have listed as Species of Greatest Conservation Need.
#
# Registration consists of a set of key/value pairs that are inserted into the registration property of the TIR table. An hstore column in PostgreSQL of key/value pairs is used in order to accommodate different registration vectors having varying attributes. Every registration has the following:
# * source - Logical name specifying the source of the registration ("SGCN" in this case)
# * registrationDate - Date/time stamp of the registration
#
# Most TIR registrations will have a "scientificname" property containing the name string used as a primary identifier. Some TIR registrations will have other identifiers that come from source material.
#
# SGCN registrations include a list of common names and taxonomic groups supplied by the state and pulled together with an array_agg function and a DISTINCT operator to create a list of unique values in a string. These values can then be reasoned on in TIR processing.

# %%
# %reload_ext autoreload

import requests,datetime
from IPython.display import display
from bis import tir
from bis2 import gc2

# %% [markdown]
# ### Get data to process
#
# This script gathers all of the unique taxonomic names (scientificname_submitted) from the SGCN data and registers them with the Taxonomic Information Registry. The query checks to make sure the taxon name is not already registered in the TIR.

# %%
q_sgcn = "SELECT scientificname_submitted scientificname, \
    array_to_string(array_agg(DISTINCT CASE WHEN commonname_submitted <> '' THEN commonname_submitted ELSE NULL END),',') commonnames, \
    array_to_string(array_agg(DISTINCT CASE WHEN taxonomicgroup_submitted <> '' THEN taxonomicgroup_submitted ELSE NULL END),',') taxonomicgroups \
    FROM sgcn.sgcn \
    WHERE scientificname_submitted <> '' \
    AND scientificname_submitted NOT IN (\
        SELECT registration->'scientificname' AS scientificname_submitted \
        FROM tir.tir \
        WHERE registration->'Source' = 'SGCN' \
    ) \
    GROUP BY scientificname_submitted"
r_sgcn = requests.get(gc2.sqlAPI("DataDistillery","BCB")+"&q="+q_sgcn).json()

# %% [markdown]
# ### Iterate over the data and process to TIR
#
# This block iterates over the unique species returned, packages up the data for the registration, and inserts them into the TIR table. It requires the following:
#
# * TIR table set up in the appropriate GC2-basede data schema
# * Registration field in the TIR table using the hstore data type
# * gc2 module from the BIS2 package (connection info for the API)
# * tir module from the BIS package (function to insert registration info)

# %%
recordCount = 0

for sgcn in r_sgcn['features']:
    recordInfoPairs = '"registrationDate" => "'+datetime.datetime.utcnow().isoformat()+'"'

    # Set source to indicate data coming from the SGCN system
    recordInfoPairs = recordInfoPairs+',"source"=>"SGCN"'

    # Set the scientific name string - a common point of registration into the TIR (was formerly "SGCN_ScientificName_Submitted")
    recordInfoPairs = recordInfoPairs+',"scientificname"=>"'+sgcn['properties']['scientificname'].replace("\'","''")+'"'

    # Set a list of the unique common names that are associated with the scientific name
    recordInfoPairs = recordInfoPairs+',"commonnames"=>"'+sgcn['properties']['commonnames'].replace("\'","''")+'"'

    # Set a list of the unique taxonomic groups (something specific to the SGCN) that are associated with the scientific name
    recordInfoPairs = recordInfoPairs+',"taxonomicgroups"=>"'+sgcn['properties']['taxonomicgroups']+'"'

    try:
        print (sgcn['properties']['scientificname'], tir.tirRegistration(gc2.sqlAPI("DataDistillery","BCB"),recordInfoPairs))
        recordCount = recordCount + 1
    except Exception as e:
        print (e)

print ("Unique records processed: "+str(recordCount))
# Out:
# Accipiter gentilis atricapillus {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
#
'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Megascops kennicottii {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Megascops trichopsis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Melanerpes formicivorus {'_execution_time': 0.063, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Melanerpes lewis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Melanerpes uropygialis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Meleagris gallopavo mexicana {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Melospiza lincolnii {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Melozone aberti {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Micrathene whitneyi {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Microphysula ingersolli {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Microtus longicaudus {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Microtus longicaudus leucophaeus {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Microtus mexicanus {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Microtus mexicanus hualpaiensis {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Microtus montanus {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Micruroides euryxanthus {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Mugil cephalus {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# ...
# name 'numProcessed' is not defined
# Sonorella rosemontensis {'_execution_time': 0.109, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella russelli {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella sabinoensis {'_execution_time': 0.072, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella santaritana {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella simmonsi {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella sitiens {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella superstitionis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella tortillita {'_execution_time': 0.07, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella tryoniana {'_execution_time': 0.103, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella vespertina {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella virilis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella walkeri {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella waltoni {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sonorella xanthenes {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sorex arizonae {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sorex merriami {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sorex nanus {'_execution_time': 0.099, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sorex palustris {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Spea intermontana {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Spermophilus lateralis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Spermophilus spilosoma {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Spermophilus tridecemlineatus {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sphyrapicus nuchalis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sphyrapicus thyroideus {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Spilogale gracilis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Spizella atrogularis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Spizella breweri {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sternula antillarum browni {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Streptocephalus dorothae {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Streptocephalus mackini {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Streptocephalus sealii {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Streptocephalus texanus {'_execution_time': 0.108, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Strix occidentalis lucida {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sturnella magna {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Stygobromus arizonensis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Succinea grosvenori {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Succinea luteola {'_execution_time': 0.064, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sylvilagus nuttallii grangeri {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Sylvilagus nuttallii pinetis {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tadarida brasiliensis {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tamias cinereicollis {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tamiasciurus hudsonicus grahamens {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tamias minimus {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tamias quadrivittatus {'_execution_time': 0.105, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tamias umbrinus {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tantilla wilcoxi {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tantilla yaquia {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Terrapene ornata {'_execution_time': 0.107, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Thamnocephalus mexicanus {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Thamnocephalus platyurus {'_execution_time': 0.079, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Thamnophis cyrtopsis {'_execution_time': 0.067, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Thamnophis eques megalops {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Thamnophis rufipunctatus {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Thomomys bottae subsimilis {'_execution_time': 0.067, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Thomomys talpoides {'_execution_time': 0.071, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Thomomys umbrinus intermedius {'_execution_time': 0.067, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Thysanophora hornii {'_execution_time': 0.079, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tiaroga cobitis {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Toxostoma bendirei {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Toxostoma lecontei {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Triops longicaudatus {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Triops newberryi {'_execution_time': 0.067, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Troglodytes pacificus {'_execution_time': 0.071, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Trogon elegans {'_execution_time': 0.067, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tryonia gilae {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tryonia quitobaquitae {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Tyrannus crassirostris {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Uma rufopunctata {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Uma scoparia {'_execution_time': 0.067, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Vallonia cyclophorella {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Vallonia perspectiva {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Valvata humeralis {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Vertigo berryi {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Vireo bellii arizonae {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Vireo vicinior {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Vitrina pellucida alaskana {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Vulpes macrotis {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Vulpes vulpes {'_execution_time': 0.069, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Xantusia arizonae {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Xantusia bezyi {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Xyrauchen texanus {'_execution_time': 0.068, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Zapus hudsonius luteus {'_execution_time': 0.067, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Zonitoides arboreus {'_execution_time': 0.065, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Zonotrichia leucophrys {'_execution_time': 0.066, 'success': True, 'auth_check': {'auth_level': None, 'success': True, 'session': None}, 'affected_rows': 1}
# name 'numProcessed' is not defined
# Unique records processed: 530
